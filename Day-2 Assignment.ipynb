# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
from numpy.random import randn, randint, uniform, sample

# %%
#assignment-1
df = pd.DataFrame(randn(10,4),columns=['a','b','c','d'])
df.plot(kind='bar',xlabel = "X-axis", ylabel = "Y-axis", title = "Bar Chart Using DataFrame",figsize = (10,10))
# Out:
# <AxesSubplot:title={'center':'Bar Chart Using DataFrame'}, xlabel='X-axis', ylabel='Y-axis'>
